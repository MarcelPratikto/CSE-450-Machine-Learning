# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd


housing = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/housing.csv')

# %%
# DataSet from Kaggle 
income = pd.read_csv('kaggle_income.csv')
income.head()
# Out:
#         id  State_Code State_Name State_ab          County            City  \
# 0  1011000           1    Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL  Barbour County      Louisville
# 2  1011020           1    Alabama       AL   Shelby County      Columbiana
# 3  1011030           1    Alabama       AL   Mobile County         Satsuma
# 4  1011040           1    Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#          Lat        Lon   Mean  Median  Stdev        sum_w
# 0  30.771450 -88.079697  38773   30506  33101  1638.260513
# 1  31.708516 -85.611039  37725   19528  43789   258.017685
# 2  33.191452 -86.615618  54606   31930  57348   926.031000
# 3  30.874343 -88.009442  63919   52814  47707   378.114619
# 4  30.250913 -88.171268  77948   67225  54270   282.320328

# %%
housing.head(10)
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  1565930130  20141104T000000         4       3.25         3760      4675
# 1  3279000420  20150115T000000         3       1.75         1460      7800
# 2   194000575  20141014T000000         4       1.00         1340      5800
# 3  2115510160  20141208T000000         3       1.75         1440      8050
# 4  7522500005  20140815T000000         2       1.50         1780      4750
# 5  3787000140  20140901T000000         3       2.25         1780      9969
# 6  7852110690  20140522T000000         4       2.50         2980      8107
# 7  5469700260  20140903T000000         4       2.25         2530     24700
# 8  8691410730  20150220T000000         4       2.50         3090      5600
# 9   114100763  20140728T000000         3       0.75         1040     15000
#
#    floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0     2.0           0     0          3  ...        2740           1020
# 1     1.0           0     0          2  ...        1040            420
# 2     1.5           0     2          3  ...        1340              0
# 3     1.0           0     0          3  ...        1440              0
# 4     1.0           0     0          4  ...        1080            700
# 5     1.0           0     0          3  ...        1450            330
# 6     2.0           0     0          3  ...        2980              0
# 7     2.0           0     0          3  ...        2530              0
# 8     2.0           0     0          3  ...        3090              0
# 9     1.0           0     0          3  ...        1040              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      2007             0    98038  47.3862 -122.048           3280
# 1      1979             0    98023  47.3035 -122.382           1310
# 2      1914             0    98116  47.5658 -122.389           1900
# 3      1985             0    98023  47.3187 -122.390           1790
# 4      1947             0    98117  47.6859 -122.395           1690
# 5      1985             0    98034  47.7286 -122.168           1950
# 6      2000             0    98065  47.5389 -121.876           2750
# 7      1974             0    98031  47.3939 -122.177           2650
# 8      2005             0    98075  47.5970 -121.979           3080
# 9      1941             0    98028  47.7639 -122.234           1410
#
#    sqft_lot15     price
# 0        4033  429900.0
# 1        7865  233000.0
# 2        5800  455000.0
# 3        7488  258950.0
# 4        5962  555000.0
# 5        7974  450000.0
# 6        7760  622500.0
# 7       24700  340000.0
# 8        5788  708000.0
# 9       19000  230000.0
#
# [10 rows x 21 columns]

# %%
filter_zip=[]
with open('filter_zip.txt') as f:
    for line in f:
      filter_zip.append(int(line.strip().rstrip(',')))

# %%
income_WA = income[income['Zip_Code'].isin(filter_zip)]
income_WA.head()
# Out:
#              id  State_Code  State_Name State_ab       County          City  \
# 30462  53011019          53  Washington       WA  King County  Maple Valley
# 30467  53011069          53  Washington       WA  King County     Carnation
# 30477  53011169          53  Washington       WA  King County     Newcastle
# 30485  53011249          53  Washington       WA  King County       Redmond
# 30488  53011279          53  Washington       WA  King County        Seatac
#
#                         Place  Type Primary  Zip_Code Area_Code     ALand  \
# 30462                  Hobart   CDP   place     98038       425  48688898
# 30467  Lake Marcel-Stillwater   CDP   place     98014       425   3302817
# 30477          Newcastle city  City   place     98059       425  11517365
# 30485            Redmond city  City   place     98052       425  42671236
# 30488             SeaTac city  City   place     98188       206  25979947
#
#        AWater        Lat         Lon    Mean  Median  Stdev        sum_w
# 30462  292010  47.411787 -122.005262  102482   89423  67425   957.466418
# 30467  147180  47.695094 -121.915104  142237  300000  57314    91.754139
# 30477   28798  47.531664 -122.165566  128325  112782  76807  1272.930995
# 30485   27137  47.678260 -122.114700  115345  103788  74443  8167.121309
# 30488  453909  47.443390 -122.298294   57563   45768  45314  6384.989475

# %%
income_median_WA =income_WA[['Zip_Code','Median']]
income_median_WA.shape
# Out:
# (189, 2)

# %%
import numpy as np
import pandas as pd

Rich = [98004, 98039, 98112]
poor = [98011, 98002, 98003, 98022, 98023, 98030, 98031, 98032, 98042, 98055, 98148, 98168, 98188, 98178, 98198]


def grade_zip(zipcode):
    if zipcode in Rich:
        return 'Rich'
    elif zipcode in poor:
        return 'Poor'
    else:
        return 'Avg'

housing['RichOrNot'] = housing['zipcode'].apply(grade_zip)

housing['zipcode'] = housing['zipcode'].astype('category')

housing['RichOrNot'].value_counts()
# Out:
# Avg     15828
# Poor     3589
# Rich      583
# Name: RichOrNot, dtype: int64

# %%
housing.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price', 'RichOrNot'],
#       dtype='object')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20000 non-null  int64
#  1   date           20000 non-null  object
#  2   bedrooms       20000 non-null  int64
#  3   bathrooms      20000 non-null  float64
#  4   sqft_living    20000 non-null  int64
#  5   sqft_lot       20000 non-null  int64
#  6   floors         20000 non-null  float64
#  7   waterfront     20000 non-null  int64
#  8   view           20000 non-null  int64
#  9   condition      20000 non-null  int64
#  10  grade          20000 non-null  int64
#  11  sqft_above     20000 non-null  int64
#  12  sqft_basement  20000 non-null  int64
#  13  yr_built       20000 non-null  int64
#  14  yr_renovated   20000 non-null  int64
#  15  zipcode        20000 non-null  category
#  16  lat            20000 non-null  float64
#  17  long           20000 non-null  float64
#  18  sqft_living15  20000 non-null  int64
#  19  sqft_lot15     20000 non-null  int64
#  20  price          20000 non-null  float64
#  21  RichOrNot      20000 non-null  object
# dtypes: category(1), float64(5), int64(14), object(2)
# memory usage: 3.2+ MB

# %%
# plt.figure(figsize=(20,15))
# box = sns.boxplot(data = housing, x="RichOrNot", y = "price")
# box, labels = plt.xticks()
# plt.xticks(rotation=90)
# plt.setp(labels, rotation=90)

# %%
housing.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.000000e+04  20000.000000  20000.000000  20000.000000  2.000000e+04
# mean   4.580297e+09      3.370200      2.115750   2079.883100  1.501533e+04
# std    2.875295e+09      0.931931      0.770134    919.433672  3.970135e+04
# min    1.000102e+06      0.000000      0.000000    290.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904955e+09      3.000000      2.250000   1910.000000  7.620000e+03
# 75%    7.309825e+09      4.000000      2.500000   2550.000000  1.071000e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.164794e+06
#
#             floors    waterfront          view     condition         grade  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       1.49645      0.007550      0.234900      3.409700      7.657700
# std        0.54095      0.086564      0.767692      0.651895      1.175287
# min        1.00000      0.000000      0.000000      1.000000      1.000000
# 25%        1.00000      0.000000      0.000000      3.000000      7.000000
# 50%        1.50000      0.000000      0.000000      3.000000      7.000000
# 75%        2.00000      0.000000      0.000000      4.000000      8.000000
# max        3.50000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated           lat  \
# count  20000.000000   20000.000000  20000.000000  20000.000000  20000.000000
# mean    1790.232900     289.650200   1971.100150     82.732150     47.559970
# std      829.587101     441.537072     29.374008    397.872344      0.138517
# min      290.000000       0.000000   1900.000000      0.000000     47.155900
# 25%     1200.000000       0.000000   1951.750000      0.000000     47.470675
# 50%     1560.000000       0.000000   1975.000000      0.000000     47.571450
# 75%     2210.000000     560.000000   1997.000000      0.000000     47.678000
# max     9410.000000    4820.000000   2015.000000   2015.000000     47.777600
#
#                long  sqft_living15    sqft_lot15         price
# count  20000.000000   20000.000000   20000.00000  2.000000e+04
# mean    -122.213897    1986.387500   12748.96040  5.394367e+05
# std        0.140649     685.211515   27076.48904  3.664334e+05
# min     -122.519000     399.000000     651.00000  7.500000e+04
# 25%     -122.328000    1490.000000    5100.00000  3.220000e+05
# 50%     -122.230000    1840.000000    7622.00000  4.500000e+05
# 75%     -122.124000    2360.000000   10088.25000  6.416250e+05
# max     -121.315000    6210.000000  871200.00000  7.700000e+06

# %%
housing['sqft_basement'].value_counts()
# Out:
# 0       12180
# 600       207
# 700       205
# 500       192
# 800       191
#         ...
# 2570        1
# 906         1
# 2050        1
# 946         1
# 2250        1
# Name: sqft_basement, Length: 301, dtype: int64

# %%
# Create a new column called 'price_per_sqft' that is the price per square foot of the house
housing['price_per_sqft_lot'] = housing['price'] / housing['sqft_lot']
housing['price_per_sqft_living'] = housing['price'] / housing['sqft_living']
housing['price_per_sqft_above'] = housing['price'] / housing['sqft_above']


housing.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.000000e+04  20000.000000  20000.000000  20000.000000  2.000000e+04
# mean   4.580297e+09      3.370200      2.115750   2079.883100  1.501533e+04
# std    2.875295e+09      0.931931      0.770134    919.433672  3.970135e+04
# min    1.000102e+06      0.000000      0.000000    290.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904955e+09      3.000000      2.250000   1910.000000  7.620000e+03
# 75%    7.309825e+09      4.000000      2.500000   2550.000000  1.071000e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.164794e+06
#
#             floors    waterfront          view     condition         grade  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       1.49645      0.007550      0.234900      3.409700      7.657700
# std        0.54095      0.086564      0.767692      0.651895      1.175287
# min        1.00000      0.000000      0.000000      1.000000      1.000000
# 25%        1.00000      0.000000      0.000000      3.000000      7.000000
# 50%        1.50000      0.000000      0.000000      3.000000      7.000000
# 75%        2.00000      0.000000      0.000000      4.000000      8.000000
# max        3.50000      1.000000      4.000000      5.000000     13.000000
#
#        ...      yr_built  yr_renovated           lat          long  \
# count  ...  20000.000000  20000.000000  20000.000000  20000.000000
# mean   ...   1971.100150     82.732150     47.559970   -122.213897
# std    ...     29.374008    397.872344      0.138517      0.140649
# min    ...   1900.000000      0.000000     47.155900   -122.519000
# 25%    ...   1951.750000      0.000000     47.470675   -122.328000
# 50%    ...   1975.000000      0.000000     47.571450   -122.230000
# 75%    ...   1997.000000      0.000000     47.678000   -122.124000
# max    ...   2015.000000   2015.000000     47.777600   -121.315000
#
#        sqft_living15    sqft_lot15         price  price_per_sqft_lot  \
# count   20000.000000   20000.00000  2.000000e+04        20000.000000
# mean     1986.387500   12748.96040  5.394367e+05           89.023563
# std       685.211515   27076.48904  3.664334e+05           94.119550
# min       399.000000     651.00000  7.500000e+04            0.163119
# 25%      1490.000000    5100.00000  3.220000e+05           33.223245
# 50%      1840.000000    7622.00000  4.500000e+05           59.217233
# 75%      2360.000000   10088.25000  6.416250e+05          107.615874
# max      6210.000000  871200.00000  7.700000e+06         2027.208539
#
#        price_per_sqft_living  price_per_sqft_above
# count           20000.000000          20000.000000
# mean              263.952817            314.264591
# std               109.808969            146.782028
# min                87.588235             87.588235
# 25%               182.296519            206.317447
# 50%               244.650734            280.000000
# 75%               317.955056            390.918887
# max               810.138889           1341.463415
#
# [8 rows x 22 columns]

# %%
housing['total_sqft'] = housing['sqft_living'] + housing['sqft_lot'] + housing['sqft_above']

housing['price_per_sqft_total'] = housing['price'] / housing['total_sqft']
housing.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.000000e+04  20000.000000  20000.000000  20000.000000  2.000000e+04
# mean   4.580297e+09      3.370200      2.115750   2079.883100  1.501533e+04
# std    2.875295e+09      0.931931      0.770134    919.433672  3.970135e+04
# min    1.000102e+06      0.000000      0.000000    290.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904955e+09      3.000000      2.250000   1910.000000  7.620000e+03
# 75%    7.309825e+09      4.000000      2.500000   2550.000000  1.071000e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.164794e+06
#
#             floors    waterfront          view     condition         grade  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       1.49645      0.007550      0.234900      3.409700      7.657700
# std        0.54095      0.086564      0.767692      0.651895      1.175287
# min        1.00000      0.000000      0.000000      1.000000      1.000000
# 25%        1.00000      0.000000      0.000000      3.000000      7.000000
# 50%        1.50000      0.000000      0.000000      3.000000      7.000000
# 75%        2.00000      0.000000      0.000000      4.000000      8.000000
# max        3.50000      1.000000      4.000000      5.000000     13.000000
#
#        ...           lat          long  sqft_living15    sqft_lot15  \
# count  ...  20000.000000  20000.000000   20000.000000   20000.00000
# mean   ...     47.559970   -122.213897    1986.387500   12748.96040
# std    ...      0.138517      0.140649     685.211515   27076.48904
# min    ...     47.155900   -122.519000     399.000000     651.00000
# 25%    ...     47.470675   -122.328000    1490.000000    5100.00000
# 50%    ...     47.571450   -122.230000    1840.000000    7622.00000
# 75%    ...     47.678000   -122.124000    2360.000000   10088.25000
# max    ...     47.777600   -121.315000    6210.000000  871200.00000
#
#               price  price_per_sqft_lot  price_per_sqft_living  \
# count  2.000000e+04        20000.000000           20000.000000
# mean   5.394367e+05           89.023563             263.952817
# std    3.664334e+05           94.119550             109.808969
# min    7.500000e+04            0.163119              87.588235
# 25%    3.220000e+05           33.223245             182.296519
# 50%    4.500000e+05           59.217233             244.650734
# 75%    6.416250e+05          107.615874             317.955056
# max    7.700000e+06         2027.208539             810.138889
#
#        price_per_sqft_above    total_sqft  price_per_sqft_total
# count          20000.000000  2.000000e+04          20000.000000
# mean             314.264591  1.888544e+04             47.967328
# std              146.782028  4.005765e+04             32.557487
# min               87.588235  2.013000e+03              0.162920
# 25%              206.317447  8.541750e+03             24.643043
# 50%              280.000000  1.130000e+04             39.625537
# 75%              390.918887  1.510275e+04             63.736866
# max             1341.463415  1.166214e+06            279.456193
#
# [8 rows x 24 columns]

# %%
# Plot Histograms with Seaborn
sns.set_style('whitegrid')
housing.hist(bins=50, figsize=(20,20))
plt.show()

# %%
# Bar Plot of value count 

features = ['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 'grade', 'view']
ncols = 2
nrows = len(features) // ncols + (len(features) % ncols> 0) 
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*5, nrows*3))

for i, feature in enumerate(features):
    row = i // ncols
    col = i % ncols
    ax[row][col].set_title(feature)
    sns.countplot(x=feature, data=housing, ax=ax[row][col]) 
    ax[row][col].set_xticklabels(ax[row][col].get_xticklabels(), rotation=90)
plt.tight_layout()
plt.show()

# %%
# find the max Year for year_builr 
last_year = housing['yr_built'].max()
first_year = housing['yr_built'].min()
print('First Year: ', first_year)
print('Last Year: ', last_year)
# Out:
# First Year:  1900
# Last Year:  2015

# %%
plt.figure(figsize=(10,5))
plt.title('Year Built')
sns.histplot(x='yr_built', data=housing)
plt.show()

# %%
yr_renovated = housing['yr_renovated']
renovated_count = yr_renovated[yr_renovated>0].value_counts()

# Plot the renovated count
plt.figure(figsize=(15,5))
plt.title('Year Renovated')
sns.barplot(x=renovated_count.index, y=renovated_count.values)
plt.xticks(rotation=90)
plt.show()

# %%
housing['grade'].value_counts()

short = [1,2,3]
average = [4,5,6,7,8,9,10]
high=[ 11,12,13]

def grade_cat(grade):
    if grade in short:
        return 'short'
    elif grade in average:
        return 'average'
    else:
        return 'high'

housing['grade_cat'] = housing['grade'].apply(grade_cat)

housing['grade_cat'].value_counts()
# Out:
# average    19534
# high         462
# short          4
# Name: grade_cat, dtype: int64

# %%
# Plot line chart the House Price by Grade Category
plt.figure(figsize=(10,5))
plt.title('House Price by Grade Category')
sns.barplot(x='grade_cat', y='price', data=housing)
plt.show()

# %%
# INCOME DATASET
sns.set_style('whitegrid')
sns.set_palette('Set1') 
plt.figure(figsize=(20,10))
sns.countplot(x='Zip_Code', hue='Type', data=income_WA)
plt.xticks(rotation=90)
plt.title('House Location by Zip_Code')
plt.show()

# %%
# Median Income by zip code
# Plot median income by zip code
plt.figure(figsize=(20,10))
sns.barplot(x='Zip_Code', y='Median', data=income_WA)
plt.title('Median Income by Zip Code')
plt.xticks(rotation=90)
plt.show()

# %%
# MERGE MEDIAN INCOME TO HOUSING DATAFRAME

housing = pd.merge(housing, income_median_WA, left_on='zipcode', right_on='Zip_Code', how='inner')
housing['Median'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(15,5))
plt.title('Housing Price')
sns.lineplot(x='yr_built', y='price', data=housing)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Housing Price')
sns.lineplot(x='yr_renovated', y='price', data=housing[housing['yr_renovated']>0])
plt.xticks(rotation=90)
plt.show()

# %%
housing['year']=  pd.to_datetime(housing['date']).dt.year

# Line plot for date and price 

plt.figure(figsize=(15,5))
plt.title('Housing Price')
sns.lineplot(x='year', y='price', data=housing)
plt.xticks(rotation=90)
plt.show()

# %%
# Group the data by zip code and calculate the average price
grouped = housing.groupby('zipcode').mean()

# Plot the average price for each zip code
plt.figure(figsize=(15,5))
plt.title('Average Price by Zip Code')
sns.lineplot(x=grouped.index, y=grouped['price'])
plt.xticks(rotation=90)
plt.show()

# %%
corr = housing.corr()
plt.figure(figsize=(25,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')

plt.show()

# %%
sns.boxplot(x='bedrooms', y='price', data=housing)
plt.show()

# %%
# Create a scatter plot of price and bedrooms , price and sqft_living, lat and Price, long and price
features = ['bedrooms', 'sqft_living', 'lat', 'long', 'zipcode', 'view', 'grade', 'condition', 'yr_built', 'yr_renovated', 'price_per_sqft_living', 'price_per_sqft_above', 'price_per_sqft_total', 'sqft_living15', 'sqft_lot15', 'waterfront', 'grade_cat']
ncols = 2
nrows = len(features) // ncols + (len(features) % ncols> 0)
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(ncols*5, nrows*3))

for i, feature in enumerate(features):
    row = i // ncols
    col = i % ncols
    ax[row][col].set_title(feature)
    sns.scatterplot(x=feature, y='price', data=housing, ax=ax[row][col])
plt.tight_layout()
plt.show()

# %%
# plot the scatter for lat and long and hue price with shapes 
plt.figure(figsize=(10,5))
plt.title('Latitude and Longitude')
sns.scatterplot(x='long', y='lat', data=housing, hue='price', palette='coolwarm', edgecolor=None, alpha=0.2)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Square Feet Living and Square Feet Lot Neighbors')
sns.scatterplot(x='price_per_sqft_living', y='price_per_sqft_above', data=housing, hue='price', palette='coolwarm', edgecolor=None, alpha=0.2)
plt.show()

# %%
model_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
           'grade', 'sqft_above', 'zip_enc', 'sqft_living15', 'sqft_lot15',
           'lat', 'long', 'view']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import xgboost as xgb
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
encoder = OneHotEncoder() 
scaler = MinMaxScaler()

housing['zipcode'] = housing['zipcode'].astype('category')
housing['zip_enc'] = housing['zipcode'].cat.codes 

housing['grade_cat'] = housing['grade_cat'].astype('category')
housing['grade_cat_enc'] = housing['grade_cat'].cat.codes
housing.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  1565930130  20141104T000000         4       3.25         3760      4675
# 1  1565930130  20141104T000000         4       3.25         3760      4675
# 2  1565930130  20141104T000000         4       3.25         3760      4675
# 3  6699940320  20150413T000000         4       2.50         2600      5188
# 4  6699940320  20150413T000000         4       2.50         2600      5188
#
#    floors  waterfront  view  condition  ...  price_per_sqft_living  \
# 0     2.0           0     0          3  ...             114.335106
# 1     2.0           0     0          3  ...             114.335106
# 2     2.0           0     0          3  ...             114.335106
# 3     2.0           0     0          3  ...             138.423077
# 4     2.0           0     0          3  ...             138.423077
#
#    price_per_sqft_above  total_sqft  price_per_sqft_total  grade_cat Zip_Code  \
# 0            156.897810       11175             38.469799    average    98038
# 1            156.897810       11175             38.469799    average    98038
# 2            156.897810       11175             38.469799    average    98038
# 3            138.423077       10388             34.645745    average    98038
# 4            138.423077       10388             34.645745    average    98038
#
#    Median  year  zip_enc  grade_cat_enc
# 0   89423  2014       20              0
# 1   71912  2014       20              0
# 2   37779  2014       20              0
# 3   89423  2015       20              0
# 4   71912  2015       20              0
#
# [5 rows x 33 columns]

# %%
zips = housing['grade_cat_enc'].unique()
zips
# Out:
# array([0, 1, 2], dtype=int8)

# %%
scale_features =  ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors','sqft_above', 'sqft_living15',
           'lat', 'long', 'view', 'sqft_lot15', 'grade']
housing[scale_features] = scaler.fit_transform(housing[scale_features])

housing.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  1565930130  20141104T000000  0.121212    0.40625     0.257403  0.003569
# 1  1565930130  20141104T000000  0.121212    0.40625     0.257403  0.003569
# 2  1565930130  20141104T000000  0.121212    0.40625     0.257403  0.003569
# 3  6699940320  20150413T000000  0.121212    0.31250     0.169324  0.004009
# 4  6699940320  20150413T000000  0.121212    0.31250     0.169324  0.004009
#
#    floors  waterfront  view  condition  ...  price_per_sqft_living  \
# 0     0.4           0   0.0          3  ...             114.335106
# 1     0.4           0   0.0          3  ...             114.335106
# 2     0.4           0   0.0          3  ...             114.335106
# 3     0.4           0   0.0          3  ...             138.423077
# 4     0.4           0   0.0          3  ...             138.423077
#
#    price_per_sqft_above  total_sqft  price_per_sqft_total  grade_cat Zip_Code  \
# 0            156.897810       11175             38.469799    average    98038
# 1            156.897810       11175             38.469799    average    98038
# 2            156.897810       11175             38.469799    average    98038
# 3            138.423077       10388             34.645745    average    98038
# 4            138.423077       10388             34.645745    average    98038
#
#    Median  year  zip_enc  grade_cat_enc
# 0   89423  2014       20              0
# 1   71912  2014       20              0
# 2   37779  2014       20              0
# 3   89423  2015       20              0
# 4   71912  2015       20              0
#
# [5 rows x 33 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(housing[model_features], housing['price'], test_size=0.2, random_state=0)

# %%
param_grid = {
    'max_depth': [2, 4, 8, 10, None],
}

# %%
xg_model = xgb.XGBRegressor(max_depth=10, learning_rate=0.1)
xg_model.fit(X_train, y_train)

y_pred_xg = xg_model.predict(X_test)

print('R2 Score: ', r2_score(y_test, y_pred_xg))
print('MAE: ', mean_absolute_error(y_test, y_pred_xg))
print('MSE: ', mean_squared_error(y_test, y_pred_xg))

# PRint types of X_Train
print(y_pred_xg)
# Out:
# [18:08:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# R2 Score:  0.9699014313863168
# MAE:  34501.85882863102
# MSE:  3169845962.030498
# [370532.4  239610.19 324232.72 ... 282901.6  764055.06 278411.97]

# %%
print(y_test)
# Out:
# 58293    395000.0
# 33651    220000.0
# 55944    310000.0
# 22096     90000.0
# 50260    219950.0
#            ...
# 2778     275000.0
# 51033    560000.0
# 8226     312000.0
# 14456    725000.0
# 59793    225000.0
# Name: price, Length: 12197, dtype: float64

# %%
plt.scatter(y_test, y_pred_xg)
plt.plot(y_test, y_test, color='red')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %%
residuals = y_test - y_pred_xg

plt.hist(residuals, bins=50)
plt.xlabel('Residuals')
plt.ylabel('Count')
plt.title('Histogram of Residuals')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Predicted Price vs Actual Price')
sns.kdeplot(y_pred_xg, label='Predicted Price')
sns.kdeplot(y_test, label='Actual Price')
plt.show()

# %%
for importance, name in sorted(zip(xg_model.feature_importances_, X_train.columns), reverse=True):
    print(name, "=", importance)
# Out:
# grade = 0.57339513
# view = 0.15072493
# sqft_living = 0.1023855
# lat = 0.075799026
# long = 0.028335191
# zip_enc = 0.025167946
# sqft_living15 = 0.0123144975
# sqft_above = 0.009712549
# sqft_lot15 = 0.00673593
# sqft_lot = 0.0053084265
# floors = 0.0046548094
# bathrooms = 0.0035431222
# bedrooms = 0.0019229243

# %%
# Plot the feature importance
plt.figure(figsize=(10,5))
plt.title('Feature Importance')
sns.barplot(x=xg_model.feature_importances_, y=X_train.columns)
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor


dt_model = DecisionTreeRegressor()


dt_model.fit(X_train, y_train)


y_pred_dt = dt_model.predict(X_test)

# Print the R2 score, MAE, MSE, and RMSE
r2_dt = r2_score(y_test, y_pred_dt)

# %%
# Use Gradient Boosting Regression
from sklearn.ensemble import GradientBoostingRegressor


gb_model = GradientBoostingRegressor()


gb_model.fit(X_train, y_train)

y_pred_gb = gb_model.predict(X_test)

# Print the R2 score, MAE, MSE, and RMSE
r2_gb = r2_score(y_test, y_pred_gb)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=100)
rf_model.fit(X_train, y_train)

y_pred_random_forest = rf_model.predict(X_test)

# Print the R2 score, MAE, MSE, and RMSE
r2_rf = r2_score(y_test, y_pred_random_forest)
print(r2_rf)
# Out:
# 0.9800513458710618

# %%
print(y_pred_random_forest)
# Out:
# [394020.   220478.5  312450.   ... 310980.   754957.07 227020.  ]

# %%
y_test
# Out:
# 58293    395000.0
# 33651    220000.0
# 55944    310000.0
# 22096     90000.0
# 50260    219950.0
#            ...
# 2778     275000.0
# 51033    560000.0
# 8226     312000.0
# 14456    725000.0
# 59793    225000.0
# Name: price, Length: 12197, dtype: float64

# %%
# Use Linear Regression
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

lr_model.fit(X_train, y_train)


y_pred_linear = lr_model.predict(X_test)

# Print the R2 score, MAE, MSE, and RMSE
r2_linear = r2_score(y_test, y_pred_linear)

# %%
plt.figure(figsize=(10,5))
plt.title('R2 Score of all the models')
sns.barplot(x=['XGBoost', 'Decision Tree', 'Gradient Boosting', 'Random Forest', 'Linear Regression'], y=[r2_score(y_test, y_pred_xg)*100, r2_score(y_test, y_pred_dt)*100, r2_score(y_test, y_pred_gb)*100, r2_score(y_test, y_pred_random_forest)*100, r2_score(y_test, y_pred_linear)*100])

plt.show()

# %%
# Pre-process an  holdout set 
holdout_url = 'https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/housing_holdout_test.csv'
holdout = pd.read_csv(holdout_url)

# %% [markdown]
# model_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#            'grade', 'sqft_above', 'zip_enc', 'sqft_living15', 'sqft_lot15',
#            'lat', 'long', 'view']

# %%
holdout.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2591820310  20141006T000000         4       2.25         2070      8893
# 1  7974200820  20140821T000000         5       3.00         2900      6730
# 2  7701450110  20140815T000000         4       2.50         3770     10893
# 3  9522300010  20150331T000000         3       3.50         4560     14608
# 4  9510861140  20140714T000000         3       2.50         2550      5376
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     2.0           0     0          4      8        2070              0
# 1     1.0           0     0          5      8        1830           1070
# 2     2.0           0     2          3     11        3770              0
# 3     2.0           0     2          3     12        4560              0
# 4     2.0           0     0          3      9        2550              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1986             0    98058  47.4388 -122.162           2390
# 1      1977             0    98115  47.6784 -122.285           2370
# 2      1997             0    98006  47.5646 -122.129           3710
# 3      1990             0    98034  47.6995 -122.228           4050
# 4      2004             0    98052  47.6647 -122.083           2250
#
#    sqft_lot15
# 0        7700
# 1        6283
# 2        9685
# 3       14226
# 4        4050

# %%
holdout['zipcode'] = holdout['zipcode'].astype('category')
holdout['zip_enc'] = holdout['zipcode'].cat.codes

# %%
holdout[scale_features] = scaler.fit_transform(holdout[scale_features])

# %%
holdout.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2591820310  20141006T000000     0.500   0.375000     0.234848  0.005024
# 1  7974200820  20140821T000000     0.625   0.500000     0.360606  0.003713
# 2  7701450110  20140815T000000     0.500   0.416667     0.492424  0.006235
# 3  9522300010  20150331T000000     0.375   0.583333     0.612121  0.008486
# 4  9510861140  20140714T000000     0.375   0.416667     0.307576  0.002893
#
#    floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0     0.4           0   0.0          4  ...    0.283675              0
# 1     0.0           0   0.0          5  ...    0.240856           1070
# 2     0.4           0   0.5          3  ...    0.586976              0
# 3     0.4           0   0.5          3  ...    0.727921              0
# 4     0.4           0   0.0          3  ...    0.369313              0
#
#    yr_built  yr_renovated  zipcode       lat      long  sqft_living15  \
# 0      1986             0    98058  0.436533  0.262927       0.318637
# 1      1977             0    98115  0.835136  0.155127       0.314629
# 2      1997             0    98006  0.645816  0.291849       0.583166
# 3      1990             0    98034  0.870238  0.205083       0.651303
# 4      2004             0    98052  0.812344  0.332165       0.290581
#
#    sqft_lot15  zip_enc
# 0    0.012308       32
# 1    0.009777       49
# 2    0.015854        5
# 3    0.023965       22
# 4    0.005788       28
#
# [5 rows x 21 columns]

# %%
holdout_X = holdout[model_features]
holdout_X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors     grade  sqft_above  \
# 0     0.500   0.375000     0.234848  0.005024     0.4  0.444444    0.283675
# 1     0.625   0.500000     0.360606  0.003713     0.0  0.444444    0.240856
# 2     0.500   0.416667     0.492424  0.006235     0.4  0.777778    0.586976
# 3     0.375   0.583333     0.612121  0.008486     0.4  0.888889    0.727921
# 4     0.375   0.416667     0.307576  0.002893     0.4  0.555556    0.369313
#
#    zip_enc  sqft_living15  sqft_lot15       lat      long  view
# 0       32       0.318637    0.012308  0.436533  0.262927   0.0
# 1       49       0.314629    0.009777  0.835136  0.155127   0.0
# 2        5       0.583166    0.015854  0.645816  0.291849   0.5
# 3       22       0.651303    0.023965  0.870238  0.205083   0.5
# 4       28       0.290581    0.005788  0.812344  0.332165   0.0

# %%
holdout_prediction = rf_model.predict(holdout_X)

# %%
df_y = pd.DataFrame({'price': holdout_prediction})

# %%
df_y.shape
# Out:
# (1613, 1)

# %%
df_y.head()
# Out:
#         price
# 0   492680.00
# 1   990941.50
# 2  1988325.10
# 3  4352766.50
# 4   881538.53

# %%
df_y.to_csv('team2-module-3-predictions.csv')
